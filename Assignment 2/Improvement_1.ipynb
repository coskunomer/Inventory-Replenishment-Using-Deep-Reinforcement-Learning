# %%
# hygese module was not working on my macbook therefore I used google colab
# this install is not needed if hygese is already installed in your environment
# !pip install hygese
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hygese in /usr/local/lib/python3.9/dist-packages (0.0.0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from hygese) (1.22.4)

# %% [markdown]
# ## **Improved Solution 1**
#
# Below you can find our first improvement to the benchmark solution. The imbalance between the holding cost and lost sales was one of the issues we encountered in our benchmark solution. In this solution, we improve upon it by using a larger action space and trying to find a balance. In benchmark solution where we replenished the stores to a level of $2 \times order-up-to$, our model converged to a solution where it mostly replenishes 9 stores. Therefore, in this solution we set a minimum of 5 as the numbers of stores to be replenished each day and therefore reduce the action space. In this solution, we are seeking a better $ratio$ in the replenishment level $ratio \times order-up-to$ while still keeping the action space rather simple.
#
# **Actions**
# <br>
# We changed the type of output we expect from the REINFORCE algorithm in this solution. While still keeping a discrete action space, we made our model to output not only how many stores to replenish, but also up to what ratio of order-up-to level to replenish at each time t.
#
# $𝑎$ $∈$ $𝒜(𝑆_{𝑡})$, where $𝐴_{𝑡}$ $∈$ $𝒜(𝑆_{𝑡})$ is a realized action at time $𝑡$. In our case, the actions are integers in the range $[0, 75]$ for each state. After model outputs an integer in this range, we then map this integer to:
# <br>
# number of stores to replenish = output % 15 + 5
# <br>
# up_to_ratio = ((action // 15)/4) + 1
# <br>
# We set a minimum 5 indicating the minimum number of stores to replenish each day.
#
# **Policy**
# <br>
# Once the decision is made by the model, we will sort the stores, depending on how far their inventories are from the corresponding demand means. Then, the first N stores that are farthest from their demand means will be replenished to an order up to level. Then, the resulting stores that have less inventory are replenished to $ratio \times order-up-to$.
# <br> <br>
# The above mentioned policy is implemented in $takeAction$ function in the gym environment.

# %%
# importing the necessary libraries
import gym
from gym import spaces
import numpy as np
import hygese as hgs
import geopy.distance
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# enable cuda if available
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))

# Solver initialization
ap = hgs.AlgorithmParameters(timeLimit=0.1)  # seconds
hgs_solver = hgs.Solver(parameters=ap, verbose=False)

class AI4LEnvironment(gym.Env):
    """Joint Replenishment Environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}

    # initialization
    def __init__(self):
        super().__init__()
        # number of stores
        self.nStores = 19
        # data dictionary, needed for hygese solver
        self.data = dict()
        self.lat = np.array([51.46455753,  # arbitrarily selected as depot
                             51.48315348,
                             51.47946524,
                             51.47989288,
                             51.47091165,
                             51.46823832,
                             51.45097352,
                             51.44236109,
                             51.44075611,
                             51.43310493,
                             51.42748611,
                             51.44209359,
                             51.41860162,
                             51.41196388,
                             51.41919040,
                             51.45204327,
                             51.47407462,
                             51.46455753,
                             51.41655806,
                             51.46071441
                             ])

        self.lon = np.array([5.441001338,  # arbitrarily selected as depot
                             5.449615716,
                             5.463520286,
                             5.478883978,
                             5.463348625,
                             5.47776818,
                             5.465205594,
                             5.47979681,
                             5.471642895,
                             5.489753169,
                             5.465033933,
                             5.408385679,
                             5.407870695,
                             5.409587309,
                             5.441001338,
                             5.517476483,
                             5.546744746,
                             5.550177973,
                             5.572865385,
                             5.609406608
                             ])

        # initializing the distance matrix
        self.data['distance_matrix'] = np.zeros(shape=[self.nStores + 1, self.nStores + 1])
        # transportation unit cost
        self.transportCost = 2.5
        # transportation fixed cost
        self.fixedTransportCost = 20

        # calculating the distance matrix that reflects the cost of transportation from a location to another  
        for i in range(0, self.nStores + 1):
            for j in range(0, self.nStores + 1):
                coords_1 = (self.lat[i], self.lon[i])
                coords_2 = (self.lat[j], self.lon[j])
                self.data['distance_matrix'][i][j] = geopy.distance.geodesic(coords_1, coords_2).km * self.transportCost
                if i == 0:
                    self.data['distance_matrix'][i][j] += self.fixedTransportCost
        # we copy the original version of this distance matrix
        # it will be used later to filter the locations for hygese solver
        self.DISTANCE_MATRIX = self.data['distance_matrix'].copy()
        # service times are asssumed to be 0
        self.data['service_times'] = np.zeros(self.nStores + 1)
        # the vehicle capacity, the number of vehicles, and depot information
        # this is stored in the 'data' dict to be compatible with hygese solver
        self.data['vehicle_capacity'] = 100
        self.data['num_vehicles'] = 19
        self.data['depot'] = 0
        # holding cost
        self.c_holding = 1
        # loss sales cost
        self.c_lost = 19
        # capacity of each store
        self.capacity = 1000
        # The maximum to be shipped to a store
        self.maxOrderQuantity = 1000
        # the current amount of inventory in each store
        self.inventories = np.zeros(self.nStores + 1)
        # information on the demand distribution
        # small, medium or large stores: 4, 10, 25 shape par.
        self.demandMean = np.array([0,  # fake depot entry to let indices match
                                    10,
                                    4,
                                    10,
                                    10,
                                    25,
                                    25,
                                    4,
                                    25,
                                    25,
                                    25,
                                    4,
                                    10,
                                    4,
                                    10,
                                    10,
                                    4,
                                    4,
                                    10,
                                    4])
        self.data['demands'] = self.demandMean.copy()
        np.random.seed(1331)
        # standard deviations for the normal distribuiton
        self.demandStdev = np.ceil(np.random.rand(self.nStores + 1) * 0.5 * self.demandMean)
        # create some fixed order up to levels
        self.orderUpTo = np.ceil(self.demandMean + 1.96 * np.sqrt(self.demandStdev))
        # for this case, action space is defined as the number of stores to replenish given a state
        # we set a minimum of 5 stores to be replenished each day to speed up training
        self.action_space = spaces.Discrete(75)
        # observation space is simply the inventory levels at each store at the start of the day
        self.observation_space = spaces.Box(low=0,
                                            high=self.capacity,
                                            shape=(self.nStores + 1,),
                                            dtype=np.int)
        # analytics for bookkeeping purposes
        self.transportCost, self.holdingCost, self.lossSales = [], [], []
        self.counter, self.holdCost, self.salesLoss, self.tCost = 0, 0, 0, 0

    def calcDirectReward(self, ind):
        # ind: indices of the stores that are going to be replenished
        # hygese solver does not cover the edge cases and throw NULL pointer error.
        # therefore we cover those cases by if-else statements to avoid error.
        # warehouse is always in the ind
        if len(ind) == 1: 
            # cost is 0 if only warehouse in ind
            cost = 0
        elif len(ind) == 2:
            # returning cost of trasnporation between warehouse and the supermarket
            # in the case where we only replenish 1 store
            # as our policy, we never replenish more than 100, therefore only 1 car is needed
            cost = self.DISTANCE_MATRIX[0][ind[1]] + self.DISTANCE_MATRIX[ind[1]][0]
        else:
            # filtering the distance matrix
            # this is crucial, otherwise hygese visits every store
            self.data['distance_matrix'] = np.take(np.take(self.DISTANCE_MATRIX, ind, axis=0), ind, axis=1)
            # solving
            result = hgs_solver.solve_cvrp(self.data)
            # getting the cost
            cost = result.cost
        return -1 * cost

    def step(self, action):
        # taking the action
        ind = self._take_action(action)
        # getting the transportation cost
        reward = self.calcDirectReward(ind)
        self.tCost += reward
        self.current_step += 1

        # generating random demand
        demands = np.zeros(self.nStores+1)
        for i in range(1, self.nStores):
            demands[i] = int(max(0, np.random.normal(self.demandMean[i], self.demandStdev[i])))
            self.inventories[i] -= demands[i]
            holdCost_temp = max(0, self.inventories[i]) * self.c_holding
            self.holdCost += holdCost_temp
            lossSales_temp = -1 * min(0, self.inventories[i]) * self.c_lost
            self.salesLoss += lossSales_temp
            reward -= (holdCost_temp + lossSales_temp)
            self.inventories[i] = max(0, self.inventories[i])
        self.counter += 1
        if self.counter == 100:
            self.holdingCost.append(self.holdCost / 100)
            self.lossSales.append(self.salesLoss / 100)
            self.transportCost.append(-self.tCost / 100)
            self.holdCost, self.salesLoss, self.tCost = 0, 0, 0
            self.counter = 0

        # our episodes consist of 20 days
        done = self.current_step >= 20
        # observed new state is the updated inventories
        obs = self.inventories
        return obs, reward, done, {}


    def _take_action(self, action):
        # in this example it is rather simple; the inventory is shipped
        n_replenish = action % 15 + 5
        up_to_ratio = ((action // 15)/4) + 1
        # calculating the difference between the current inventory and demand means
        deficit = (self.inventories[1:] - self.demandMean[1:])
        # getting the indices that would sort this array and taking the indices of  
        # supermarkets that has the most deficit
        ind = deficit.argsort()[:n_replenish]
        # sorting the indices
        ind.sort()
        actual_ind = [0]
        # copying the inventories before the action
        old_inv = self.inventories.copy()
        # looping over the indices of over stores that are going to be replenished
        for i in ind:
            # ordering if their inventory is smaller than the orderUpTo inventory
            if self.inventories[i+1] < self.orderUpTo[i+1] * up_to_ratio:
                self.inventories[i+1] = self.orderUpTo[i+1] * up_to_ratio
                actual_ind.append(i+1)
        '''self.data['demands'] is not actually demands, but action. hygese solver
        requires it to be called "demands". we are filtering them since we only need
        to consider the stores that we are going to replenish'''
        self.data['demands'] = np.take((self.inventories - old_inv).copy(), actual_ind, axis=0)
        self.data['service_times'] = np.zeros(len(actual_ind))
        # returning the indices of the stores that are going to be replenished
        return actual_ind

    def analytics(self):
        return self.transportCost, self.holdingCost, self.lossSales
        
    def reset(self):
        # reset the state of the environment to an initial state
        # to be more realistic, we are assigning random ineventory between 0 and 10 to each store.
        self.inventories = np.array([0]+list(np.random.randint(low=0, high=11, size=self.nStores)))
        # resetting the step parameter
        self.current_step = 0
        return self.inventories

    def render(self, mode='human', close=False):
        print("No rendering implemented")
# Out:
# Using cpu device

# %%
# neural network
class PolicyNet(nn.Module):
    def __init__(self, env):
        super().__init__()
        # dimension of observation space, 20
        self.n_inputs = env.observation_space.shape[0]
        # number of outputs is 20, how many stores to replenish [0, 19] 
        self.n_outputs = env.action_space.n
        # neural network structure
        self.network = nn.Sequential(
            nn.Linear(self.n_inputs, 256), 
            nn.ReLU(), 
            nn.Linear(256, 64),
            nn.ReLU(), 
            nn.Linear(64, self.n_outputs),
            nn.Softmax(dim=-1))
    # given a state, returns the action probabilities
    def predict(self, state):
        action_probs = self.network(torch.FloatTensor(state).to(device))
        return action_probs

# discounts the rewards with gamma = 0.9
def discount_rewards(rewards, gamma=0.9):
    r = np.array([gamma**i * rewards[i] for i in range(len(rewards))])
    r = r[::-1].cumsum()[::-1]
    return r - r.mean()

# main structure of the REINFORCE algorithm
def reinforce(env, policy_estimator, num_episodes=500, batch_size=10, gamma=0.5):
    # bookkeeping
    total_rewards = []
    avg_rewards = []
    batch_rewards = []
    batch_actions = []
    batch_states = []
    batch_counter = 1
    
    # we will use adam optimizer with a particular learning rate that we optimized
    optimizer = optim.Adam(policy_estimator.network.parameters(), lr=0.001)
    # getting an integer for every action in the action space
    action_space = np.arange(env.action_space.n)
    # setting episode to 0
    ep = 0
    # looping over the number of episodes
    while ep < num_episodes:
        # resetting the state at the beginning of each episode
        s_0 = env.reset()
        # bookkeeping
        states = []
        rewards = []
        actions = []
        done = False
        # looping over until the end of the episode
        while not done:
            # getting the action probabilites
            action_probs = policy_estimator.predict(s_0).detach().cpu().numpy()
            # picking an action from the above prob. distribution
            action = np.random.choice(action_space, p=action_probs)
            # observing the new state and the rewards
            s_1, r, done, _ = env.step(action)
            # bookkeeping
            states.append(s_0)
            rewards.append(r)
            actions.append(action)
            s_0 = s_1
            
            # batching if done
            if done:
                batch_rewards.extend(discount_rewards(rewards, gamma))
                batch_states.extend(states)
                batch_actions.extend(actions)
                batch_counter += 1
                # dividing by 20 since every episode is of length 20
                total_rewards.append(sum(rewards) / 20)
                
                # updating the network once the episode is finished
                if batch_counter == batch_size:
                    # resetting gradients of optimizer to zero 
                    optimizer.zero_grad()
                    # getting the state, reward, and action tensors
                    state_tensor = torch.FloatTensor(batch_states)
                    reward_tensor = torch.FloatTensor(batch_rewards).to(device)
                    action_tensor = torch.LongTensor(batch_actions).to(device)
                    
                    # calculating the resulting loss
                    logprob = torch.log(policy_estimator.predict(state_tensor))
                    selected_logprobs = reward_tensor * torch.gather(logprob, 1, action_tensor.view(action_tensor.shape[0],1)).squeeze()
                    loss = -selected_logprobs.mean()
                    
                    # calculating backward propagation
                    loss.backward()
                    # updating the gradients
                    optimizer.step()
                    # bookkepping
                    batch_rewards = []
                    batch_actions = []
                    batch_states = []
                    batch_counter = 1
                # getting the average reward of the latest 3 episodes
                avg_reward = np.mean(total_rewards[-60:])
                avg_rewards.append(avg_reward)
                print("Ep: {} Average of last 60: {:.2f}".format(ep + 1, avg_reward))
                ep += 1
    return total_rewards, avg_rewards

# %%
# initializing the environment
env = AI4LEnvironment()
# initializng the model
policy_est = PolicyNet(env).to(device)
# training 
rewards, avg_rewards = reinforce(env, policy_est)
# plotting
plt.plot(rewards)
plt.plot(avg_rewards)
plt.xlabel("Number of training episodes")
plt.ylabel("Average Reward")
plt.savefig('benchmark.png')
plt.show()
# Out:
# Ep: 1 Average of last 60: -467.09
# Ep: 2 Average of last 60: -493.73
# Ep: 3 Average of last 60: -503.18
# Ep: 4 Average of last 60: -494.37
# Ep: 5 Average of last 60: -487.09
# Ep: 6 Average of last 60: -481.69
# Ep: 7 Average of last 60: -473.54
# Ep: 8 Average of last 60: -493.39
# Ep: 9 Average of last 60: -486.77
# Ep: 10 Average of last 60: -489.60
# Ep: 11 Average of last 60: -483.31
# Ep: 12 Average of last 60: -479.61
# Ep: 13 Average of last 60: -477.95
# Ep: 14 Average of last 60: -477.19
# Ep: 15 Average of last 60: -476.07
# Ep: 16 Average of last 60: -472.99
# Ep: 17 Average of last 60: -468.10
# Ep: 18 Average of last 60: -467.19
# Ep: 19 Average of last 60: -467.29
# Ep: 20 Average of last 60: -468.79
# Ep: 21 Average of last 60: -474.96
# Ep: 22 Average of last 60: -473.27
# Ep: 23 Average of last 60: -473.27
# Ep: 24 Average of last 60: -472.35
# Ep: 25 Average of last 60: -470.39
# Ep: 26 Average of last 60: -470.40
# Ep: 27 Average of last 60: -467.73
# Ep: 28 Average of last 60: -467.56
# Ep: 29 Average of last 60: -465.85
# Ep: 30 Average of last 60: -467.90
# Ep: 31 Average of last 60: -469.57
# Ep: 32 Average of last 60: -467.03
# Ep: 33 Average of last 60: -465.48
# Ep: 34 Average of last 60: -463.61
# Ep: 35 Average of last 60: -463.01
# Ep: 36 Average of last 60: -463.95
# Ep: 37 Average of last 60: -462.90
# Ep: 38 Average of last 60: -462.29
# Ep: 39 Average of last 60: -460.64
# Ep: 40 Average of last 60: -459.52
# Ep: 41 Average of last 60: -459.57
# Ep: 42 Average of last 60: -458.69
# Ep: 43 Average of last 60: -457.28
# Ep: 44 Average of last 60: -457.07
# Ep: 45 Average of last 60: -457.08
# Ep: 46 Average of last 60: -457.47
# Ep: 47 Average of last 60: -459.12
# Ep: 48 Average of last 60: -461.34
# Ep: 49 Average of last 60: -465.23
# Ep: 50 Average of last 60: -465.30
# Ep: 51 Average of last 60: -464.71
# Ep: 52 Average of last 60: -463.38
# Ep: 53 Average of last 60: -462.28
# Ep: 54 Average of last 60: -461.54
# Ep: 55 Average of last 60: -462.58
# Ep: 56 Average of last 60: -461.77
# Ep: 57 Average of last 60: -460.55
# Ep: 58 Average of last 60: -460.50
# Ep: 59 Average of last 60: -460.45
# Ep: 60 Average of last 60: -461.67
# Ep: 61 Average of last 60: -461.36
# Ep: 62 Average of last 60: -460.07
# Ep: 63 Average of last 60: -458.51
# Ep: 64 Average of last 60: -457.96
# Ep: 65 Average of last 60: -458.13
# Ep: 66 Average of last 60: -457.40
# Ep: 67 Average of last 60: -458.08
# Ep: 68 Average of last 60: -455.09
# Ep: 69 Average of last 60: -455.34
# Ep: 70 Average of last 60: -454.48
# Ep: 71 Average of last 60: -454.32
# Ep: 72 Average of last 60: -454.20
# Ep: 73 Average of last 60: -453.90
# Ep: 74 Average of last 60: -454.02
# Ep: 75 Average of last 60: -453.39
# Ep: 76 Average of last 60: -455.40
# Ep: 77 Average of last 60: -455.52
# Ep: 78 Average of last 60: -455.73
# Ep: 79 Average of last 60: -454.61
# Ep: 80 Average of last 60: -452.95
# Ep: 81 Average of last 60: -451.32
# Ep: 82 Average of last 60: -450.45
# Ep: 83 Average of last 60: -449.19
# Ep: 84 Average of last 60: -448.37
# Ep: 85 Average of last 60: -448.77
# Ep: 86 Average of last 60: -449.09
# Ep: 87 Average of last 60: -449.07
# Ep: 88 Average of last 60: -448.51
# Ep: 89 Average of last 60: -448.12
# Ep: 90 Average of last 60: -446.16
# Ep: 91 Average of last 60: -443.82
# Ep: 92 Average of last 60: -443.83
# Ep: 93 Average of last 60: -443.49
# Ep: 94 Average of last 60: -444.15
# Ep: 95 Average of last 60: -443.28
# Ep: 96 Average of last 60: -441.72
# Ep: 97 Average of last 60: -441.30
# Ep: 98 Average of last 60: -440.63
# Ep: 99 Average of last 60: -440.67
# Ep: 100 Average of last 60: -440.28
# Ep: 101 Average of last 60: -439.01
# Ep: 102 Average of last 60: -438.86
# Ep: 103 Average of last 60: -438.62
# Ep: 104 Average of last 60: -437.84
# Ep: 105 Average of last 60: -436.73
# Ep: 106 Average of last 60: -435.28
# Ep: 107 Average of last 60: -433.00
# Ep: 108 Average of last 60: -430.22
# Ep: 109 Average of last 60: -425.82
# Ep: 110 Average of last 60: -424.51
# Ep: 111 Average of last 60: -423.82
# Ep: 112 Average of last 60: -423.81
# Ep: 113 Average of last 60: -423.75
# Ep: 114 Average of last 60: -423.10
# Ep: 115 Average of last 60: -420.97
# Ep: 116 Average of last 60: -420.53
# Ep: 117 Average of last 60: -420.41
# Ep: 118 Average of last 60: -419.23
# Ep: 119 Average of last 60: -418.00
# Ep: 120 Average of last 60: -415.54
# Ep: 121 Average of last 60: -414.50
# Ep: 122 Average of last 60: -414.08
# Ep: 123 Average of last 60: -413.52
# Ep: 124 Average of last 60: -412.66
# Ep: 125 Average of last 60: -412.06
# Ep: 126 Average of last 60: -411.66
# Ep: 127 Average of last 60: -410.47
# Ep: 128 Average of last 60: -409.36
# Ep: 129 Average of last 60: -408.32
# Ep: 130 Average of last 60: -406.98
# Ep: 131 Average of last 60: -406.57
# Ep: 132 Average of last 60: -405.83
# Ep: 133 Average of last 60: -405.33
# Ep: 134 Average of last 60: -404.22
# Ep: 135 Average of last 60: -403.77
# Ep: 136 Average of last 60: -401.56
# Ep: 137 Average of last 60: -401.49
# Ep: 138 Average of last 60: -400.18
# Ep: 139 Average of last 60: -399.98
# Ep: 140 Average of last 60: -399.68
# Ep: 141 Average of last 60: -398.03
# Ep: 142 Average of last 60: -398.32
# Ep: 143 Average of last 60: -398.31
# Ep: 144 Average of last 60: -398.01
# Ep: 145 Average of last 60: -397.03
# Ep: 146 Average of last 60: -395.22
# Ep: 147 Average of last 60: -394.99
# Ep: 148 Average of last 60: -394.38
# Ep: 149 Average of last 60: -394.24
# Ep: 150 Average of last 60: -393.84
# Ep: 151 Average of last 60: -394.29
# Ep: 152 Average of last 60: -394.24
# Ep: 153 Average of last 60: -394.23
# Ep: 154 Average of last 60: -393.46
# Ep: 155 Average of last 60: -393.53
# Ep: 156 Average of last 60: -393.24
# Ep: 157 Average of last 60: -393.07
# Ep: 158 Average of last 60: -392.84
# Ep: 159 Average of last 60: -392.86
# Ep: 160 Average of last 60: -392.74
# Ep: 161 Average of last 60: -392.93
# Ep: 162 Average of last 60: -392.54
# Ep: 163 Average of last 60: -392.80
# Ep: 164 Average of last 60: -392.61
# Ep: 165 Average of last 60: -392.53
# Ep: 166 Average of last 60: -392.65
# Ep: 167 Average of last 60: -392.44
# Ep: 168 Average of last 60: -392.16
# Ep: 169 Average of last 60: -392.16
# Ep: 170 Average of last 60: -392.10
# Ep: 171 Average of last 60: -391.94
# Ep: 172 Average of last 60: -391.81
# Ep: 173 Average of last 60: -391.60
# Ep: 174 Average of last 60: -391.55
# Ep: 175 Average of last 60: -391.46
# Ep: 176 Average of last 60: -391.40
# Ep: 177 Average of last 60: -391.42
# Ep: 178 Average of last 60: -391.75
# Ep: 179 Average of last 60: -391.84
# Ep: 180 Average of last 60: -391.92
# Ep: 181 Average of last 60: -392.02
# Ep: 182 Average of last 60: -391.51
# Ep: 183 Average of last 60: -391.46
# Ep: 184 Average of last 60: -391.42
# Ep: 185 Average of last 60: -390.61
# Ep: 186 Average of last 60: -390.65
# Ep: 187 Average of last 60: -390.60
# Ep: 188 Average of last 60: -390.48
# Ep: 189 Average of last 60: -390.54
# Ep: 190 Average of last 60: -390.67
# Ep: 191 Average of last 60: -390.67
# Ep: 192 Average of last 60: -390.81
# Ep: 193 Average of last 60: -390.51
# Ep: 194 Average of last 60: -390.18
# Ep: 195 Average of last 60: -389.97
# Ep: 196 Average of last 60: -389.51
# Ep: 197 Average of last 60: -389.48
# Ep: 198 Average of last 60: -389.45
# Ep: 199 Average of last 60: -389.36
# Ep: 200 Average of last 60: -389.45
# Ep: 201 Average of last 60: -389.20
# Ep: 202 Average of last 60: -389.00
# Ep: 203 Average of last 60: -388.90
# Ep: 204 Average of last 60: -388.88
# Ep: 205 Average of last 60: -388.95
# Ep: 206 Average of last 60: -388.95
# Ep: 207 Average of last 60: -388.92
# Ep: 208 Average of last 60: -388.74
# Ep: 209 Average of last 60: -389.02
# Ep: 210 Average of last 60: -389.29
# Ep: 211 Average of last 60: -389.04
# Ep: 212 Average of last 60: -389.24
# Ep: 213 Average of last 60: -389.15
# Ep: 214 Average of last 60: -388.99
# Ep: 215 Average of last 60: -388.96
# Ep: 216 Average of last 60: -389.08
# Ep: 217 Average of last 60: -389.02
# Ep: 218 Average of last 60: -389.06
# Ep: 219 Average of last 60: -388.79
# Ep: 220 Average of last 60: -388.78
# Ep: 221 Average of last 60: -388.73
# Ep: 222 Average of last 60: -388.53
# Ep: 223 Average of last 60: -388.51
# Ep: 224 Average of last 60: -388.49
# Ep: 225 Average of last 60: -388.53
# Ep: 226 Average of last 60: -388.48
# Ep: 227 Average of last 60: -388.63
# Ep: 228 Average of last 60: -388.75
# Ep: 229 Average of last 60: -388.78
# Ep: 230 Average of last 60: -388.79
# Ep: 231 Average of last 60: -388.69
# Ep: 232 Average of last 60: -388.71
# Ep: 233 Average of last 60: -388.64
# Ep: 234 Average of last 60: -388.76
# Ep: 235 Average of last 60: -388.76
# Ep: 236 Average of last 60: -388.70
# Ep: 237 Average of last 60: -388.76
# Ep: 238 Average of last 60: -388.46
# Ep: 239 Average of last 60: -388.39
# Ep: 240 Average of last 60: -388.55
# Ep: 241 Average of last 60: -388.43
# Ep: 242 Average of last 60: -388.34
# Ep: 243 Average of last 60: -388.41
# Ep: 244 Average of last 60: -388.38
# Ep: 245 Average of last 60: -388.44
# Ep: 246 Average of last 60: -388.36
# Ep: 247 Average of last 60: -388.47
# Ep: 248 Average of last 60: -388.70
# Ep: 249 Average of last 60: -388.66
# Ep: 250 Average of last 60: -388.58
# Ep: 251 Average of last 60: -388.49
# Ep: 252 Average of last 60: -388.48
# Ep: 253 Average of last 60: -388.28
# Ep: 254 Average of last 60: -388.18
# Ep: 255 Average of last 60: -388.22
# Ep: 256 Average of last 60: -388.26
# Ep: 257 Average of last 60: -388.10
# Ep: 258 Average of last 60: -388.01
# Ep: 259 Average of last 60: -388.36
# Ep: 260 Average of last 60: -388.44
# Ep: 261 Average of last 60: -388.47
# Ep: 262 Average of last 60: -388.41
# Ep: 263 Average of last 60: -388.34
# Ep: 264 Average of last 60: -388.56
# Ep: 265 Average of last 60: -388.72
# Ep: 266 Average of last 60: -388.77
# Ep: 267 Average of last 60: -388.86
# Ep: 268 Average of last 60: -388.97
# Ep: 269 Average of last 60: -388.91
# Ep: 270 Average of last 60: -388.55
# Ep: 271 Average of last 60: -388.51
# Ep: 272 Average of last 60: -388.51
# Ep: 273 Average of last 60: -388.58
# Ep: 274 Average of last 60: -388.60
# Ep: 275 Average of last 60: -388.75
# Ep: 276 Average of last 60: -388.71
# Ep: 277 Average of last 60: -388.69
# Ep: 278 Average of last 60: -389.00
# Ep: 279 Average of last 60: -389.15
# Ep: 280 Average of last 60: -389.07
# Ep: 281 Average of last 60: -388.96
# Ep: 282 Average of last 60: -389.06
# Ep: 283 Average of last 60: -389.12
# Ep: 284 Average of last 60: -389.18
# Ep: 285 Average of last 60: -389.13
# Ep: 286 Average of last 60: -389.05
# Ep: 287 Average of last 60: -388.87
# Ep: 288 Average of last 60: -388.81
# Ep: 289 Average of last 60: -388.70
# Ep: 290 Average of last 60: -388.69
# Ep: 291 Average of last 60: -388.73
# Ep: 292 Average of last 60: -388.79
# Ep: 293 Average of last 60: -388.85
# Ep: 294 Average of last 60: -388.77
# Ep: 295 Average of last 60: -388.72
# Ep: 296 Average of last 60: -388.80
# Ep: 297 Average of last 60: -388.77
# Ep: 298 Average of last 60: -388.66
# Ep: 299 Average of last 60: -388.70
# Ep: 300 Average of last 60: -388.45
# Ep: 301 Average of last 60: -388.49
# Ep: 302 Average of last 60: -388.59
# Ep: 303 Average of last 60: -388.43
# Ep: 304 Average of last 60: -388.55
# Ep: 305 Average of last 60: -388.48
# Ep: 306 Average of last 60: -388.50
# Ep: 307 Average of last 60: -388.38
# Ep: 308 Average of last 60: -388.15
# Ep: 309 Average of last 60: -388.12
# Ep: 310 Average of last 60: -388.33
# Ep: 311 Average of last 60: -388.61
# Ep: 312 Average of last 60: -388.56
# Ep: 313 Average of last 60: -388.55
# Ep: 314 Average of last 60: -388.65
# Ep: 315 Average of last 60: -388.67
# Ep: 316 Average of last 60: -388.91
# Ep: 317 Average of last 60: -388.98
# Ep: 318 Average of last 60: -389.03
# Ep: 319 Average of last 60: -388.73
# Ep: 320 Average of last 60: -388.87
# Ep: 321 Average of last 60: -388.86
# Ep: 322 Average of last 60: -388.99
# Ep: 323 Average of last 60: -388.92
# Ep: 324 Average of last 60: -389.09
# Ep: 325 Average of last 60: -388.86
# Ep: 326 Average of last 60: -389.09
# Ep: 327 Average of last 60: -389.06
# Ep: 328 Average of last 60: -388.96
# Ep: 329 Average of last 60: -388.76
# Ep: 330 Average of last 60: -388.97
# Ep: 331 Average of last 60: -389.00
# Ep: 332 Average of last 60: -388.76
# Ep: 333 Average of last 60: -388.62
# Ep: 334 Average of last 60: -388.63
# Ep: 335 Average of last 60: -388.40
# Ep: 336 Average of last 60: -388.25
# Ep: 337 Average of last 60: -388.28
# Ep: 338 Average of last 60: -388.22
# Ep: 339 Average of last 60: -388.09
# Ep: 340 Average of last 60: -388.41
# Ep: 341 Average of last 60: -388.53
# Ep: 342 Average of last 60: -388.54
# Ep: 343 Average of last 60: -388.31
# Ep: 344 Average of last 60: -388.33
# Ep: 345 Average of last 60: -388.33
# Ep: 346 Average of last 60: -388.34
# Ep: 347 Average of last 60: -388.37
# Ep: 348 Average of last 60: -388.34
# Ep: 349 Average of last 60: -388.46
# Ep: 350 Average of last 60: -388.56
# Ep: 351 Average of last 60: -388.78
# Ep: 352 Average of last 60: -388.84
# Ep: 353 Average of last 60: -388.75
# Ep: 354 Average of last 60: -389.28
# Ep: 355 Average of last 60: -389.51
# Ep: 356 Average of last 60: -389.45
# Ep: 357 Average of last 60: -389.59
# Ep: 358 Average of last 60: -389.83
# Ep: 359 Average of last 60: -389.85
# Ep: 360 Average of last 60: -389.91
# Ep: 361 Average of last 60: -389.95
# Ep: 362 Average of last 60: -389.96
# Ep: 363 Average of last 60: -390.03
# Ep: 364 Average of last 60: -390.17
# Ep: 365 Average of last 60: -390.34
# Ep: 366 Average of last 60: -390.29
# Ep: 367 Average of last 60: -390.16
# Ep: 368 Average of last 60: -390.37
# Ep: 369 Average of last 60: -390.36
# Ep: 370 Average of last 60: -390.16
# Ep: 371 Average of last 60: -390.01
# Ep: 372 Average of last 60: -389.97
# Ep: 373 Average of last 60: -390.14
# Ep: 374 Average of last 60: -390.09
# Ep: 375 Average of last 60: -390.11
# Ep: 376 Average of last 60: -389.74
# Ep: 377 Average of last 60: -389.76
# Ep: 378 Average of last 60: -389.89
# Ep: 379 Average of last 60: -389.81
# Ep: 380 Average of last 60: -389.61
# Ep: 381 Average of last 60: -389.62
# Ep: 382 Average of last 60: -389.47
# Ep: 383 Average of last 60: -389.53
# Ep: 384 Average of last 60: -389.70
# Ep: 385 Average of last 60: -389.69
# Ep: 386 Average of last 60: -389.75
# Ep: 387 Average of last 60: -389.93
# Ep: 388 Average of last 60: -390.30
# Ep: 389 Average of last 60: -390.24
# Ep: 390 Average of last 60: -390.15
# Ep: 391 Average of last 60: -390.31
# Ep: 392 Average of last 60: -390.40
# Ep: 393 Average of last 60: -390.53
# Ep: 394 Average of last 60: -390.42
# Ep: 395 Average of last 60: -390.57
# Ep: 396 Average of last 60: -390.72
# Ep: 397 Average of last 60: -391.02
# Ep: 398 Average of last 60: -390.68
# Ep: 399 Average of last 60: -390.76
# Ep: 400 Average of last 60: -390.59
# Ep: 401 Average of last 60: -390.42
# Ep: 402 Average of last 60: -390.49
# Ep: 403 Average of last 60: -390.39
# Ep: 404 Average of last 60: -390.42
# Ep: 405 Average of last 60: -390.61
# Ep: 406 Average of last 60: -390.72
# Ep: 407 Average of last 60: -390.66
# Ep: 408 Average of last 60: -390.77
# Ep: 409 Average of last 60: -390.86
# Ep: 410 Average of last 60: -390.98
# Ep: 411 Average of last 60: -390.82
# Ep: 412 Average of last 60: -390.67
# Ep: 413 Average of last 60: -390.70
# Ep: 414 Average of last 60: -390.28
# Ep: 415 Average of last 60: -390.25
# Ep: 416 Average of last 60: -390.38
# Ep: 417 Average of last 60: -390.42
# Ep: 418 Average of last 60: -390.19
# Ep: 419 Average of last 60: -390.17
# Ep: 420 Average of last 60: -390.10
# Ep: 421 Average of last 60: -390.34
# Ep: 422 Average of last 60: -390.29
# Ep: 423 Average of last 60: -390.19
# Ep: 424 Average of last 60: -390.15
# Ep: 425 Average of last 60: -389.95
# Ep: 426 Average of last 60: -390.06
# Ep: 427 Average of last 60: -390.04
# Ep: 428 Average of last 60: -389.92
# Ep: 429 Average of last 60: -389.92
# Ep: 430 Average of last 60: -389.88
# Ep: 431 Average of last 60: -389.85
# Ep: 432 Average of last 60: -389.75
# Ep: 433 Average of last 60: -389.75
# Ep: 434 Average of last 60: -389.79
# Ep: 435 Average of last 60: -389.84
# Ep: 436 Average of last 60: -389.96
# Ep: 437 Average of last 60: -389.98
# Ep: 438 Average of last 60: -389.93
# Ep: 439 Average of last 60: -389.84
# Ep: 440 Average of last 60: -389.86
# Ep: 441 Average of last 60: -389.76
# Ep: 442 Average of last 60: -389.73
# Ep: 443 Average of last 60: -389.73
# Ep: 444 Average of last 60: -389.28
# Ep: 445 Average of last 60: -389.29
# Ep: 446 Average of last 60: -389.47
# Ep: 447 Average of last 60: -389.37
# Ep: 448 Average of last 60: -389.33
# Ep: 449 Average of last 60: -389.35
# Ep: 450 Average of last 60: -389.59
# Ep: 451 Average of last 60: -389.33
# Ep: 452 Average of last 60: -389.63
# Ep: 453 Average of last 60: -389.86
# Ep: 454 Average of last 60: -390.10
# Ep: 455 Average of last 60: -389.83
# Ep: 456 Average of last 60: -390.05
# Ep: 457 Average of last 60: -389.80
# Ep: 458 Average of last 60: -389.97
# Ep: 459 Average of last 60: -389.84
# Ep: 460 Average of last 60: -390.13
# Ep: 461 Average of last 60: -390.15
# Ep: 462 Average of last 60: -390.05
# Ep: 463 Average of last 60: -390.13
# Ep: 464 Average of last 60: -390.29
# Ep: 465 Average of last 60: -390.38
# Ep: 466 Average of last 60: -390.21
# Ep: 467 Average of last 60: -390.41
# Ep: 468 Average of last 60: -390.34
# Ep: 469 Average of last 60: -390.29
# Ep: 470 Average of last 60: -390.13
# Ep: 471 Average of last 60: -390.27
# Ep: 472 Average of last 60: -390.25
# Ep: 473 Average of last 60: -390.45
# Ep: 474 Average of last 60: -390.57
# Ep: 475 Average of last 60: -390.45
# Ep: 476 Average of last 60: -390.31
# Ep: 477 Average of last 60: -389.99
# Ep: 478 Average of last 60: -390.08
# Ep: 479 Average of last 60: -389.99
# Ep: 480 Average of last 60: -390.06
# Ep: 481 Average of last 60: -389.74
# Ep: 482 Average of last 60: -389.63
# Ep: 483 Average of last 60: -389.91
# Ep: 484 Average of last 60: -390.11
# Ep: 485 Average of last 60: -390.52
# Ep: 486 Average of last 60: -390.42
# Ep: 487 Average of last 60: -390.48
# Ep: 488 Average of last 60: -390.45
# Ep: 489 Average of last 60: -390.73
# Ep: 490 Average of last 60: -390.85
# Ep: 491 Average of last 60: -391.16
# Ep: 492 Average of last 60: -391.24
# Ep: 493 Average of last 60: -391.16
# Ep: 494 Average of last 60: -391.08
# Ep: 495 Average of last 60: -391.21
# Ep: 496 Average of last 60: -391.23
# Ep: 497 Average of last 60: -391.21
# Ep: 498 Average of last 60: -391.59
# Ep: 499 Average of last 60: -391.67
# Ep: 500 Average of last 60: -391.60

# %%
# resetting the environment for simulation
env.reset()
# bookkeeping
rewards = []
# 10 episodes, each with 20 days
for _ in range(10):
    obs = env.reset()
    done = False
    while not done:
        # getting the predictions from the trained model
        action_probs = policy_est.predict(obs)
        action = np.random.choice(np.arange(75), p=action_probs.detach().cpu().numpy())
        n_replenish = action % 15 + 5
        up_to_ratio = ((action // 15)/4) + 1
        obs, reward, done, b = env.step(action)
        print("NEW STATE:", obs, "ACTION:", [n_replenish, up_to_ratio], "REWARD:", reward)
        rewards.append(reward)
print(f"Average Reward of the Benchmark Policy = {np.array(rewards).mean()}")
# Out:
# NEW STATE: [ 0 11  6  9 14 15 16  4 15 16 20  5  9 10 14 10  6  6 17  7] ACTION: [18, 1.5] REWARD: -425.3151754632812
# NEW STATE: [ 0  6  8  9 13 17 10 10 15 15 15  5  8  9 13 14  7  7  9 10] ACTION: [18, 1.5] REWARD: -374.28226858663237
# NEW STATE: [ 0 11  8 10  8 15 27  5 19 14 15 10  7  2 21 10  6  8 17 10] ACTION: [18, 1.5] REWARD: -398.80219686176173
# NEW STATE: [ 0  8  4  8 13 13 35  8 12 17 17  3  8  8 18  8  5  5 10 10] ACTION: [18, 1.5] REWARD: -392.79465076330456
# NEW STATE: [ 0  6  2  9 12 16  0  3  6 14 32  2  8  7 10 11  5  7 13 10] ACTION: [18, 1.5] REWARD: -434.246312420255
# NEW STATE: [ 0  8  6 10  7 15 37  4 25 15 28  8  9  3 10  9  4  6 12 10] ACTION: [18, 1.5] REWARD: -411.52115783786684
# NEW STATE: [ 0  7  7  7  9 16 16  8 24 16 19  7 10  5 19  5  4  6 13 10] ACTION: [18, 1.5] REWARD: -361.4638517564787
# NEW STATE: [ 0  7  6  9 17 15 41  5 18 16 35  6  9  5 12  8  6  7 15 10] ACTION: [18, 1.5] REWARD: -431.7407794804202
# NEW STATE: [ 0  8  5  7 13 15  6  6 18 14 11 10  8  8 14  9  5  4 16 10] ACTION: [18, 1.5] REWARD: -340.4638517564787
# NEW STATE: [ 0  8  7  7  9 17 24  5 20 16 23  6  8  5 15 10  6  8  8 10] ACTION: [18, 1.5] REWARD: -388.3485525900589
# NEW STATE: [ 0 11  6  9 14 15 31 10 17 16 12  7  7  6 15 10  7  8 12 10] ACTION: [18, 1.5] REWARD: -398.3487040035584
# NEW STATE: [ 0 12 10  8 12 15 32  6 21 14 14  1  9  6 11 11  5  7 14 10] ACTION: [18, 1.5] REWARD: -393.1374644440681
# NEW STATE: [ 0 10  9  8  9 16 20  7 17 15 24  8  8  7 15  9  5  6  7 10] ACTION: [18, 1.5] REWARD: -368.3620465259089
# NEW STATE: [ 0  9  5  7  9 14 20  7 19 15 20  1  9  5 15  8  5  7 15 10] ACTION: [18, 1.5] REWARD: -374.51904905584183
# NEW STATE: [ 0  9  4  9 14 16 18  5 10 15 14  9  9  2 13 10  7  9 14 10] ACTION: [18, 1.5] REWARD: -373.3485525900589
# NEW STATE: [ 0 12  5  9 10 15 32  7 18 15 36  6  8  7 15  8  6  6 12 10] ACTION: [18, 1.5] REWARD: -413.34855259005894
# NEW STATE: [ 0 11  4  8 14 16 25  7 17 15 17  4  9  6 14  7  6  5 15 10] ACTION: [18, 1.5] REWARD: -363.6475729124276
# NEW STATE: [ 0  9  5  9 14 16 46  6 22 17 16  5 10  7 10 13  6  6 13 10] ACTION: [18, 1.5] REWARD: -416.3485525900589
# NEW STATE: [ 0 10  5  7 12 16 39  8 18 13 12  7  7 10 13 14  5  7 10 10] ACTION: [18, 1.5] REWARD: -381.3620465259089
# NEW STATE: [ 0 12  7  8 15 13 16  5 24 14 16  3  9  2  8  9  7  7  8 10] ACTION: [18, 1.5] REWARD: -352.07699100185687
# NEW STATE: [ 0 12  7 10  8 17 33  6 20 16 32  6  9  9 11  8  6  6 15 10] ACTION: [18, 1.5] REWARD: -452.1040873172904
# NEW STATE: [ 0 11  6  9 12 15  0  6 17 18 35  8  8  6 20 12  6  5 13 10] ACTION: [18, 1.5] REWARD: -370.4638517564787
# NEW STATE: [ 0  8  6  8 12 15 15  8 17 16  0 10 10  8  6  8  6  9 10 10] ACTION: [18, 1.5] REWARD: -396.84404646303904
# NEW STATE: [ 0 13  8 10  9 16 35  6 20 13 26  4  7  5 14  8  5  6  9 10] ACTION: [18, 1.5] REWARD: -400.3485525900589
# NEW STATE: [ 0  7  8  8  6 15  2  8 24 16 45  5 10  7 14 11  5 10 13 10] ACTION: [18, 1.5] REWARD: -383.07699100185687
# NEW STATE: [ 0 16  6 10  8 16 24  6 18 16 15  6  9  5  9  8  6  9 12 10] ACTION: [18, 1.5] REWARD: -365.4400889697099
# NEW STATE: [ 0 11  9  8  6 18 19  5 14 15 34 10  9  9 15  6  5  8  9 10] ACTION: [18, 1.5] REWARD: -395.1374644440681
# NEW STATE: [ 0 12  7 10  8 17 39  9 19 16 23  7  9  6 10  9  4  4 10 10] ACTION: [18, 1.5] REWARD: -385.651027592578
# NEW STATE: [ 0  6  7 11 16 15 29  9 23 15 30  8  8  9 13  6  5  3  9 10] ACTION: [18, 1.5] REWARD: -390.3620465259089
# NEW STATE: [ 0 14  6  9 18 15 19  1 18 15 32  8  9 10 18  9  5  6 12 10] ACTION: [18, 1.5] REWARD: -383.154147297881
# NEW STATE: [ 0  9  7  9  9 15 22  6 24 16 17  3  8  3 11  9  6  9  9 10] ACTION: [18, 1.5] REWARD: -358.6487893295838
# NEW STATE: [ 0 10  6  9 12 16 20  5 19 16 24  5  8  9 15  9  7  9 13 10] ACTION: [18, 1.5] REWARD: -397.80219686176173
# NEW STATE: [ 0 10  6  9 12 14 34  7 12 16 17  6 11  6 12  8  4  9 13 10] ACTION: [18, 1.5] REWARD: -388.7155594536532
# NEW STATE: [ 0 10  5  8  9 18 21  7 16 15 32  7 11  3 13 10  4  7  8 10] ACTION: [18, 1.5] REWARD: -372.3620465259089
# NEW STATE: [ 0  8  7  8  9 16 27  9 12 15 21 10 11  6  9  6  5  9 17 10] ACTION: [18, 1.5] REWARD: -374.0043404138283
# NEW STATE: [ 0  8  6  9  9 16 48  7 20 14 16  3  8  6 16 14  6  7  7 10] ACTION: [18, 1.5] REWARD: -403.6175361689387
# NEW STATE: [ 0  6 10  7  6 16 23  8 14 16 35  9  8  5  6 10  6 10  8 10] ACTION: [18, 1.5] REWARD: -372.07699100185687
# NEW STATE: [ 0 10  8  9 14 15 35  7 22 15 14  8 10  3 11 10  4 10 12 10] ACTION: [18, 1.5] REWARD: -384.8440464630391
# NEW STATE: [ 0  7  7 10  8 16 28  7 20 14 15  5  9  6  9  9  7  7  8 10] ACTION: [18, 1.5] REWARD: -360.3620465259089
# NEW STATE: [ 0 10  9  8  9 17 33  9 20 15 17  6  9  7 15 12  8  7 10 10] ACTION: [18, 1.5] REWARD: -406.5288663710709
# NEW STATE: [ 0  5  8  9  6 18 19  6 18 16 17  5  9  6 14 14  6  5 11 10] ACTION: [18, 1.5] REWARD: -422.4969438306845
# NEW STATE: [ 0  9  6  7  9 16 21  3 26 15 39 10 10  6 13 10  5  3 10 10] ACTION: [18, 1.5] REWARD: -403.80219686176173
# NEW STATE: [ 0  9  3 10 12 16 45  7 17 16  0  5  8  4  7  7  5 10  7 10] ACTION: [18, 1.5] REWARD: -446.6475729124276
# NEW STATE: [ 0 11  3 10  8 15 26 10 23 15 11  4  8  7  8 13  5  5 10 10] ACTION: [18, 1.5] REWARD: -388.06127049061627
# NEW STATE: [ 0 12  8  8 11 16 38 10 24 15 47  8  8  2  3  9  6  4 12 10] ACTION: [18, 1.5] REWARD: -426.1374644440681
# NEW STATE: [ 0  9  7 10  7 15 26  8 18 17 41  8  7  8 11  7  8  6 10 10] ACTION: [18, 1.5] REWARD: -386.6475729124276
# NEW STATE: [ 0  6  5  9  7 14 25  5 24 15 18  5  9  8 15  9  4  3 12 10] ACTION: [18, 1.5] REWARD: -356.6475729124276
# NEW STATE: [ 0 13  8  9  4 16 16  6 13 13 33  5  8  9  8 10  7  9 15 10] ACTION: [18, 1.5] REWARD: -387.3487040035584
# NEW STATE: [ 0 12  8  9 10 13  9  5 17 15  0  8  8  3 17  9  6  9 11 10] ACTION: [18, 1.5] REWARD: -431.9170096632307
# NEW STATE: [ 0  6  2  9  9 15 29  3 16 14 15  8  7  4  9  6  6  5 11 10] ACTION: [18, 1.5] REWARD: -370.42764389971023
# NEW STATE: [ 0 12 10  8 10 16 31  8 20 14 39  6  8  5 12 10  6  7  9 10] ACTION: [18, 1.5] REWARD: -417.34855259005894
# NEW STATE: [ 0 12  8  9 12 15 22  5 16 16 16  6 10  6  7  8  6  7  9 10] ACTION: [18, 1.5] REWARD: -353.6475729124276
# NEW STATE: [ 0  7  7 10 14 15 33  6 19 15 14  8  9  4  8  8  5  5 10 10] ACTION: [18, 1.5] REWARD: -383.34855259005894
# NEW STATE: [ 0 11  6  9 14 17 31  4 16 16 28  5  8  3 12 11  7  4 16 10] ACTION: [18, 1.5] REWARD: -413.0541765018255
# NEW STATE: [ 0 11  8  9 12 14 37  5 16 15 24  6  9  5  9  7  6  5 10 10] ACTION: [18, 1.5] REWARD: -367.34583942889356
# NEW STATE: [ 0  8 10  8 13 15  0  8 17 15 21  8 10  5 12 11  5  9 10 10] ACTION: [18, 1.5] REWARD: -393.1751760208391
# NEW STATE: [ 0  9  6  9 10 16 31  7 17 15 28  8  8  8 11  6  7  6 11 10] ACTION: [18, 1.5] REWARD: -398.43982826522137
# NEW STATE: [ 0  9  6  9 17 13 25  6 27 15 21  1  8  5 10  8  4  5 13 10] ACTION: [18, 1.5] REWARD: -386.51904905584183
# NEW STATE: [ 0 12  5  8  5 17 41  9 21 15 30  4 10  8 12  9  4  9 12 10] ACTION: [18, 1.5] REWARD: -426.86359486850847
# NEW STATE: [ 0  9  4  9  7 18 23  5 19 17  0  5  9  4 15  7  7  8  8 10] ACTION: [18, 1.5] REWARD: -489.4638517564787
# NEW STATE: [ 0 11  9 10  6 16 37  9 23 17 41  6  8  8 21  9  8  2 18 10] ACTION: [18, 1.5] REWARD: -487.554429514512
# NEW STATE: [ 0 13  3  7 10 16 22  7 12 15 14  6  6  6  8 10  6  2 13 10] ACTION: [18, 1.5] REWARD: -335.92473622302623
# NEW STATE: [ 0 12  6 10 13 15  4  7 14 15 24  6  8  4  4  9  7  6  6 10] ACTION: [18, 1.5] REWARD: -356.34855259005894
# NEW STATE: [ 0  8 10  8 15 18 38  2 14 15 12  7  8  8 14  9  5  7 10 10] ACTION: [18, 1.5] REWARD: -396.4397083104577
# NEW STATE: [ 0 12  7 10  9 15 34  6 20 16 10  7  7 10 13 11  6  6 15 10] ACTION: [18, 1.5] REWARD: -385.23711289817123
# NEW STATE: [ 0 12  5 10 15 15 21  7 20 15 48  4  9  6 11  9  4  2 11 10] ACTION: [18, 1.5] REWARD: -392.3620465259089
# NEW STATE: [ 0 11  3 10  9 18 30  9 24 16 32  8  9 10  5  8  6  8 10 10] ACTION: [18, 1.5] REWARD: -394.21731492361823
# NEW STATE: [ 0 10 10  8 11 13 26  5 18 17  4  8  7  5 13 13  5  6 11 10] ACTION: [18, 1.5] REWARD: -353.6475729124276
# NEW STATE: [ 0  9  5  9 14 15 24  6 20 17  6  8  8  5 13 10  5  5  9 10] ACTION: [18, 1.5] REWARD: -373.5288663710709
# NEW STATE: [ 0  8  8 10 11 13 23  9 22 15 35  6  6  6  9 10  5  6 14 10] ACTION: [18, 1.5] REWARD: -402.3485525900589
# NEW STATE: [ 0  5  7  8 12 15 17  6 20 18 23  7  7  8 10 11  6  6 15 10] ACTION: [18, 1.5] REWARD: -368.84404646303904
# NEW STATE: [ 0  9  8  7 12 16 10  5 20 17  3  3  9  7  9 11  7  3 11 10] ACTION: [18, 1.5] REWARD: -352.43982826522137
# NEW STATE: [ 0  9  6  8 10 15 19  7 15 15 41  6  9  6 12  7  4  6 13 10] ACTION: [18, 1.5] REWARD: -394.3485525900589
# NEW STATE: [ 0  8  6  9  9 14 36  6 24 16 27  6  9  6 15  8  5  4 13 10] ACTION: [18, 1.5] REWARD: -391.2705151558078
# NEW STATE: [ 0  8 10  8 14 16 16  5 18 17 32  9  9  7 16  9  7  9  5 10] ACTION: [18, 1.5] REWARD: -378.4638517564787
# NEW STATE: [ 0  8  7  9 15 13 41  3 20 15  0  6  8  6  9 11  5  7 12 10] ACTION: [18, 1.5] REWARD: -456.6322106005603
# NEW STATE: [ 0  8  4  8 13 16 26  7 13 18 21  7  9  8 14  7  6  3 12 10] ACTION: [18, 1.5] REWARD: -396.06127049061627
# NEW STATE: [ 0  8  8  9 14 16 32  7 21 16  6  7  7  7 14 10  6 10 10 10] ACTION: [18, 1.5] REWARD: -393.1565680851289
# NEW STATE: [ 0  8  8 10  6 17  0  6 17 17 16  6  6  7 12 11  5  8 12 10] ACTION: [18, 1.5] REWARD: -378.3620465259089
# NEW STATE: [ 0 12  4  8 14 16 24  8 14 14 25  7  8  7 14 10  4  4 12 10] ACTION: [18, 1.5] REWARD: -391.34855259005894
# NEW STATE: [ 0  6  3 10 11 14 22  7 17 15  8  5  8  6 17  6  5  0  9 10] ACTION: [18, 1.5] REWARD: -400.4737180004814
# NEW STATE: [ 0 11  2  8  8 14 39  7 17 16 48  6  9  8 10 11  6  4 15 10] ACTION: [18, 1.5] REWARD: -435.42764389971023
# NEW STATE: [ 0  8  6  9 12 16 15  6 22 14  2  5  7  9 15  9  5  7 11 10] ACTION: [18, 1.5] REWARD: -341.6475729124276
# NEW STATE: [ 0 11  6  9 12 16 20  5 19 16 25  7  8  7 15 10  5  9  4 10] ACTION: [18, 1.5] REWARD: -390.34855259005894
# NEW STATE: [ 0 10  6  9 17 14 25  4 22 16 36  7  6  4  8 10  7 10 10 10] ACTION: [18, 1.5] REWARD: -405.51904905584183
# NEW STATE: [ 0 11  7  7 14 15 32  8 21 17  5  9  9  8  7  8  5 10 16 10] ACTION: [18, 1.5] REWARD: -376.8440464630391
# NEW STATE: [ 0  8 10  9 15 16  0  7 18 14 12  5 11  3 17  8  5  5 16 10] ACTION: [18, 1.5] REWARD: -555.120448513067
# NEW STATE: [ 0  6  6  8  8 16 25  6 16 15 33  3  9  8 15 11  5  9 13 10] ACTION: [18, 1.5] REWARD: -410.518799620109
# NEW STATE: [ 0  9  5  9  9 17 24  7 15 15 20  7  8  8 12  6  6  8 12 10] ACTION: [18, 1.5] REWARD: -363.651027592578
# NEW STATE: [ 0 13  6  9  6 16 15  2 23 15 19  6  9  3 19  7  7  5 13 10] ACTION: [18, 1.5] REWARD: -379.3485525900589
# NEW STATE: [ 0  7  3  7 16 15 33  6 13 15 17  8  8  9 13  9  6  7 13 10] ACTION: [18, 1.5] REWARD: -401.4153292133429
# NEW STATE: [ 0  8  7  8 10 17  0  8 19 15 20  4  7  6  9 11  8  3 10 10] ACTION: [18, 1.5] REWARD: -341.23711289817123
# NEW STATE: [ 0  6  6 10 11 16 21  8 12 18 39  7  9  4  8  8  5  6 14 10] ACTION: [18, 1.5] REWARD: -396.4397083104577
# NEW STATE: [ 0 10  6  9 14 17 16  7 17 19  0 10  9  5 13 13  4  4 14 10] ACTION: [18, 1.5] REWARD: -354.8440464630391
# NEW STATE: [ 0 11  5  8 10 14 12  9 13 14 36  7  9  6 14  8  4  5  8 10] ACTION: [18, 1.5] REWARD: -379.34855259005894
# NEW STATE: [ 0  9  9  8 12 15 11  8 19 16 29  9  7  3  7  7  5  8 12 10] ACTION: [18, 1.5] REWARD: -388.7430177434144
# NEW STATE: [ 0 11  6  7 12 15 34  6 21 14 48  2  9  7 10  8  5  6 10 10] ACTION: [18, 1.5] REWARD: -417.19359878876446
# NEW STATE: [ 0  5  9 11 13 14 37  4 20 13 48  4  8  8 15  8  7  4 14 10] ACTION: [18, 1.5] REWARD: -405.6475729124276
# NEW STATE: [ 0 10  9  8 10 15 18  6 13 16 32  6  7  8 15 12  5  7  8 10] ACTION: [18, 1.5] REWARD: -368.6475729124276
# NEW STATE: [ 0  5  5  8 17 16 19  5 23 15 12  5  9  7  9 15  5  5 11 10] ACTION: [18, 1.5] REWARD: -357.651027592578
# NEW STATE: [ 0 11  9 10 10 13 24  9 11 15 22  7  8  5  7  8  5  8  8 10] ACTION: [18, 1.5] REWARD: -397.2163617964038
# NEW STATE: [ 0  9  5  9 12 16 26  5 17 15 18  3  8  8 10  8  5  3 10 10] ACTION: [18, 1.5] REWARD: -372.5288663710709
# NEW STATE: [ 0  9  8  8 14 15 27  9 22 15 14  8  9  7 15 12  5  6 10 10] ACTION: [18, 1.5] REWARD: -399.34855259005894
# NEW STATE: [ 0 10  6  9 14 15 28  7 25 15 34  5  8  2  3  9  4  7  9 10] ACTION: [18, 1.5] REWARD: -392.7155594536532
# NEW STATE: [ 0  6  7  8  8 16 25  7 20 15  1  6  9  8 15 10  5  9  6 10] ACTION: [18, 1.5] REWARD: -348.9170096632307
# NEW STATE: [ 0  5  6  8 11 16 19  9 18 15 24  3  7  4  7 10  4  7 10 10] ACTION: [18, 1.5] REWARD: -369.34855259005894
# NEW STATE: [ 0  9  8  9 13 15 39  7 14 16 24  7  7  7 14  9  4  9  7 10] ACTION: [18, 1.5] REWARD: -404.34855259005894
# NEW STATE: [ 0 12  5  8  8 17 22  4 24 15 25  7  8  5 19 12  5  6 12 10] ACTION: [18, 1.5] REWARD: -383.7123726500266
# NEW STATE: [ 0 12  9  7 13 15 25  9 18 17 23  6  9  2  6  8  6  9 13 10] ACTION: [18, 1.5] REWARD: -375.430388814777
# NEW STATE: [ 0 12  6  8  8 15 18  8 17 15 36  7  8  3 12 11  6 10  9 10] ACTION: [18, 1.5] REWARD: -394.1374644440681
# NEW STATE: [ 0  8  5  8 13 14 18  6 17 15 29  8  8  4  7 10  5  8 11 10] ACTION: [18, 1.5] REWARD: -360.651027592578
# NEW STATE: [ 0 10  7  9 11 16 14  7 17 16 16  8  9  5  9 10  5  5 12 10] ACTION: [18, 1.5] REWARD: -372.34855259005894
# NEW STATE: [ 0  3  5  7  9 15 32  8 19 16  7 10  9  8 14  6  5  3  7 10] ACTION: [18, 1.5] REWARD: -369.3485525900589
# NEW STATE: [ 0 12  6  9  8 16  2  6 20 16 34  6  9  5 12 12  5  8 11 10] ACTION: [18, 1.5] REWARD: -392.246312420255
# NEW STATE: [ 0  9  6  7 12 16 26  7 18 14  0  6  9  5  6 10  6  5 14 10] ACTION: [18, 1.5] REWARD: -425.2083084115666
# NEW STATE: [ 0 10  8  8 11 14 25  4 21 15 14  5  6  6 12 11  7  6 14 10] ACTION: [18, 1.5] REWARD: -383.1636620739197
# NEW STATE: [ 0 10  8  8  4 18 39  7 18 15 30  8 10  7 12 12  7  9 10 10] ACTION: [18, 1.5] REWARD: -417.5288663710709
# NEW STATE: [ 0 11  9  8  9 16 11  8 21 16 20  4  8  5 10  7  4  7 14 10] ACTION: [18, 1.5] REWARD: -351.4638517564787
# NEW STATE: [ 0 11  5  9 10 16 41  6 20 15 31  8  9  5 13 10  6  8 16 10] ACTION: [18, 1.5] REWARD: -424.80219686176173
# NEW STATE: [ 0  8  5  8 14 16 18  9 14 15 29  5 10  6 12  8  5  7  8 10] ACTION: [18, 1.5] REWARD: -360.4638517564787
# NEW STATE: [ 0  8  6 10 11 15  5  5 21 17 20  9  6  5  9 10  5  9 12 10] ACTION: [18, 1.5] REWARD: -414.01063785279086
# NEW STATE: [ 0  9  5 11 13 15 35  6 19 15 29  6  7  3 21  8  6  6  7 10] ACTION: [18, 1.5] REWARD: -407.34855259005894
# NEW STATE: [ 0  8  4  8  9 16 17  6 22 14  0  6  8 10  9  9  5  6 13 10] ACTION: [18, 1.5] REWARD: -338.50335201496864
# NEW STATE: [ 0 10  4  8 12 17  6  3 17 16  7  4  9  5 15 12  5  5 10 10] ACTION: [18, 1.5] REWARD: -351.34855259005894
# NEW STATE: [ 0  6  6  8 12 18 28  4 19 16 12  7  9  7 11  9  5 10  8 10] ACTION: [18, 1.5] REWARD: -381.34855259005894
# NEW STATE: [ 0  6  6  7 13 16 29  9 19 18 18  4  9  6 16 11  5  4 12 10] ACTION: [18, 1.5] REWARD: -393.1374644440681
# NEW STATE: [ 0  9  8  8 13 18 20  8 24 16  4  4  8  5  9 11  5  7 13 10] ACTION: [18, 1.5] REWARD: -373.5899803194506
# NEW STATE: [ 0  7  6  9  9 16 20  5 28 17 43  7  9  6 12  8  5  6 13 10] ACTION: [18, 1.5] REWARD: -411.1374644440681
# NEW STATE: [ 0 10  3  9 12 16  5  7 22 16 22  6  8  5  9 10  6  5  8 10] ACTION: [18, 1.5] REWARD: -342.6475729124276
# NEW STATE: [ 0  8  7  8 15 15 30  7 13 14 27  7  8  5 10 11  6  4 11 10] ACTION: [18, 1.5] REWARD: -392.34855259005894
# NEW STATE: [ 0  8  6  8 10 14 29  6 20 16 21  6  7  4 14  7  7  5 12 10] ACTION: [18, 1.5] REWARD: -383.5899803194506
# NEW STATE: [ 0 11 10 10  6 14 29  7 20 15 37  6  8  7  8 11  7  4  9 10] ACTION: [18, 1.5] REWARD: -404.34870400355834
# NEW STATE: [ 0 11  8 11  9 14 45  7 20 13 37  8  7  8  8  5  5  3 13 10] ACTION: [18, 1.5] REWARD: -395.6475729124276
# NEW STATE: [ 0 11  4  8 13 18  6  7 19 16  9  4  7  6 14 11  6 10 13 10] ACTION: [18, 1.5] REWARD: -345.4638517564787
# NEW STATE: [ 0  9  8  8 15 16 20  1 19 17  7  4  6  6 10  6  5  3 16 10] ACTION: [18, 1.5] REWARD: -362.3485525900589
# NEW STATE: [ 0  8  3 10 11 17 31  6 20 16 48  6  9  5 12  9  8  9 11 10] ACTION: [18, 1.5] REWARD: -425.3485525900589
# NEW STATE: [ 0 11  7  8 11 16 30  7 19 15 14  4  9  8 15  4  5  7 12 10] ACTION: [18, 1.5] REWARD: -365.6475729124276
# NEW STATE: [ 0 10  6  8 11 15 31  6 17 15 35  5  8 10  4 11  6  5 15 10] ACTION: [18, 1.5] REWARD: -403.3487040035584
# NEW STATE: [ 0  9  7  8 13 14 36  6 25 16  0  6  6  4 13  5  6  5 16 10] ACTION: [18, 1.5] REWARD: -457.8440464630391
# NEW STATE: [ 0  8  1  9 12 15 23  6 18 15 16  6 10  6  8  9  5  6  9 10] ACTION: [18, 1.5] REWARD: -376.67969238141984
# NEW STATE: [ 0 12  7  8 12 16 37  6 14 16 33  4  8  7 13 11  5  7  9  9] ACTION: [18, 1.5] REWARD: -447.3151754632812
# NEW STATE: [ 0 12  8 10 11 17  8  9 19 15 12  6  8  4 16  9  6  8 12 10] ACTION: [18, 1.5] REWARD: -353.4638517564787
# NEW STATE: [ 0 13  6  7 11 14 38  8 18 13 22  5  7  7  9 11  5  9  9 10] ACTION: [18, 1.5] REWARD: -398.3485525900589
# NEW STATE: [ 0 10  3  9 18 17 18  2 18 16 23  8 10  8  7 11  5  9 18 10] ACTION: [18, 1.5] REWARD: -379.07699100185687
# NEW STATE: [ 0  8  8  8  7 17 21  4 22 16 20  7  8  4 11 11  4  6  8 10] ACTION: [18, 1.5] REWARD: -385.13976105981016
# NEW STATE: [ 0  9  7 10 14 14 25  5 17 16  8  6  8  5  9 10  6  6  9 10] ACTION: [18, 1.5] REWARD: -370.3485525900589
# NEW STATE: [ 0  8  8  8 15 15 10  9 18 15 42  7 10  8 13 11  7  9 10 10] ACTION: [18, 1.5] REWARD: -409.3485525900589
# NEW STATE: [ 0  7  8 12 16 14 16  7 21 16 30  5  9  5  5  7  6  3  9 10] ACTION: [18, 1.5] REWARD: -361.03795341619616
# NEW STATE: [ 0  6 10  8 11 14 20  6 13 15 22  8  9  8  1 10  5  8 15 10] ACTION: [18, 1.5] REWARD: -375.34855259005894
# NEW STATE: [ 0  8  5  8 17 15 18  7 17 17 17  6  7 10 17 12  5 10 13 10] ACTION: [18, 1.5] REWARD: -395.34855259005894
# NEW STATE: [ 0  8  5  9 10 15 21  8 18 16 28  5 10  9  3  9  6  6 17 10] ACTION: [18, 1.5] REWARD: -397.7407794804202
# NEW STATE: [ 0 12  5  9 14 15 14  7 31 15 29  9  8  3  0  7  5  7  9 10] ACTION: [18, 1.5] REWARD: -401.6175361689387
# NEW STATE: [ 0  5  7  7 13 15 14 10 16 15 25  8  8  3 18  4  5  8 10 10] ACTION: [18, 1.5] REWARD: -375.51904905584183
# NEW STATE: [ 0  7  5  9 10 15 30  6 26 17 19  6 10  7  8  8  7  4 13 10] ACTION: [18, 1.5] REWARD: -401.7407794804202
# NEW STATE: [ 0 10  5 10 14 15 28 10 16 17 34  6  7  4 10  8  6  8 19 10] ACTION: [18, 1.5] REWARD: -412.1374644440681
# NEW STATE: [ 0 10  9  9 11 16 19  7 22 16 22  6  7  6  8  9  6  7 12 10] ACTION: [18, 1.5] REWARD: -368.6322106005603
# NEW STATE: [ 0 11  6  8 11 16 27  9 20 16 35  7  9  5 11  8  6  8 10 10] ACTION: [18, 1.5] REWARD: -408.5288663710709
# NEW STATE: [ 0 11  6  9 13 16 34  8 16 16 18 10  9  6 13 10  5  5 17 10] ACTION: [18, 1.5] REWARD: -385.6475729124276
# NEW STATE: [ 0 10  9  7  9 16 21  6  7 14 21  6  8  4 11 12  7  8  7 10] ACTION: [18, 1.5] REWARD: -351.3620465259089
# NEW STATE: [ 0 10  6  9 14 17 18  8 17 17 36  6  7  9  2 13  6  6 13 10] ACTION: [18, 1.5] REWARD: -400.34855259005894
# NEW STATE: [ 0  8  6  8 15 17 32  8 17 15 18  9  8  1 13 10  4  7 13  9] ACTION: [18, 1.5] REWARD: -431.3151754632812
# NEW STATE: [ 0 13  4  8 11 14 23  7 23 16 36  5  9  7 15 12  7  3  8 10] ACTION: [18, 1.5] REWARD: -390.7123726500266
# NEW STATE: [ 0  8  8 10 13 15 31  7 19 15 19  8  8  4 10 10  4  9 13 10] ACTION: [18, 1.5] REWARD: -374.6475729124276
# NEW STATE: [ 0  6  4 10  9 16 17  7 23 14  8  5  9 10 15  9  7  4 12 10] ACTION: [18, 1.5] REWARD: -367.7155594536532
# NEW STATE: [ 0  8  9 10 10 16 33  6 27 15 19  8  9  6  8 10  6  7 18 10] ACTION: [18, 1.5] REWARD: -410.80219686176173
# NEW STATE: [ 0 10  9  8  9 14 39  5 18 15 30  5  9  6 18  4  7  7  7 10] ACTION: [18, 1.5] REWARD: -375.4244530277108
# NEW STATE: [ 0  8  4  9 17 16  0  6 11 15 17  9  8  7  5 13  5  4 10 10] ACTION: [18, 1.5] REWARD: -422.4638517564787
# NEW STATE: [ 0  9  8 10  9 15 20  5 29 16 37  5  8  7 14  9  5  8 14 10] ACTION: [18, 1.5] REWARD: -426.1396411050465
# NEW STATE: [ 0  5  5  7 12 15 35  9 21 15 18  9  9  5 12  9  7  3 15 10] ACTION: [18, 1.5] REWARD: -374.6475729124276
# NEW STATE: [ 0  8  7  8 11 16  0  7 14 15  8  5  9  8  8  9  5  7  9 10] ACTION: [18, 1.5] REWARD: -401.23711289817123
# NEW STATE: [ 0  7  8 11 14 15 13  8 17 15 20  7  8  6 16 12  5  7  8 10] ACTION: [18, 1.5] REWARD: -386.57511761421654
# NEW STATE: [ 0  8  6  9 11 15 32  8 15 16 10  5 11  5 13 11  6  8 15 10] ACTION: [18, 1.5] REWARD: -390.34855259005894
# NEW STATE: [ 0 10  3  9 14 15  0  7 12 14 29  4  7  6  6  7  4  7 15 10] ACTION: [18, 1.5] REWARD: -471.07699100185687
# NEW STATE: [ 0  9  8 11 13 16 42  7 18 16 35  9  9  4 18  9  6  8  9 10] ACTION: [18, 1.5] REWARD: -435.4397083104577
# NEW STATE: [ 0 11  9  8 10 16 27  7 20 18 24  3  8  8 13 11  6  7 11 10] ACTION: [18, 1.5] REWARD: -380.4638517564787
# NEW STATE: [ 0  7  8  9  7 15  6  4 17 16 44  7  7 10  8  6  5  5 12 10] ACTION: [18, 1.5] REWARD: -351.4045875926584
# NEW STATE: [ 0 12  6  9 11 16 24  5 21 14 12  6  9  7 12  8  4  5 11 10] ACTION: [18, 1.5] REWARD: -386.7430177434144
# NEW STATE: [ 0 10  8  8 11 17 34  6 22 15 30  8  9  4 12 11  5  6  9 10] ACTION: [18, 1.5] REWARD: -411.34855259005894
# NEW STATE: [ 0 11  8  8 13 15  4  5 19 16 17  6 11  5  8  9  4  8 16 10] ACTION: [18, 1.5] REWARD: -346.4638517564787
# NEW STATE: [ 0 12  5 10 15 16 20  8 17 17 17  7  8  7 11 11  5  7 14 10] ACTION: [18, 1.5] REWARD: -393.3485525900589
# NEW STATE: [ 0 13 10  8 10 14 34  6 17 17 19  9  9  7  5 12  5  5 13 10] ACTION: [18, 1.5] REWARD: -445.3596884903243
# NEW STATE: [ 0 10  7  8 14 15 16  5 27 15 37 10  9  8  8 13  5  2  7 10] ACTION: [18, 1.5] REWARD: -384.3620465259089
# NEW STATE: [ 0 10  7 10 13 16  1  8 26 15  5  1  9  9 10 11  4  6 10 10] ACTION: [18, 1.5] REWARD: -339.08190572609243
# NEW STATE: [ 0  9  6  7 13 15  9  6 13 15 25 10  7  7  7  9  6  5  9 10] ACTION: [18, 1.5] REWARD: -366.4397083104577
# NEW STATE: [ 0  8  6  9 13 15 15 10 14 15  0  8  9  8 18 12  4  2  9 10] ACTION: [18, 1.5] REWARD: -399.3485525900589
# NEW STATE: [ 0 10  9  9 13 15  6  6 27 15  5  6  8  8  8 14  4  4 15 10] ACTION: [18, 1.5] REWARD: -378.42764389971023
# NEW STATE: [ 0  8  8  9  9 15 23  6 16 16 17  5  8  6  6 12  6  6  6 10] ACTION: [18, 1.5] REWARD: -368.34855259005894
# NEW STATE: [ 0 10  7  7 12 15 18  8 19 16 31  6  9  6 12 11  6  8 12 10] ACTION: [18, 1.5] REWARD: -399.3485525900589
# NEW STATE: [ 0 10 10  8 14 15 12  9 27 15 42  9  8  9  8 11  6  6 13 10] ACTION: [18, 1.5] REWARD: -414.7155594536532
# NEW STATE: [ 0  9  7  9 13 14 16  7 25 16  0 10  9  8 15  8  5  3  6 10] ACTION: [18, 1.5] REWARD: -421.03795341619616
# NEW STATE: [ 0  7  9 10  5 17 40  6 21 15 32 10  8  6 17 11  5  8  6 10] ACTION: [18, 1.5] REWARD: -419.34855259005894
# NEW STATE: [ 0  8 10  9 12 14 15  9 20 15 27  9  7  4 14  9  7  6 12 10] ACTION: [18, 1.5] REWARD: -370.4638517564787
# NEW STATE: [ 0  7  4  7 14 16 15  8 11 16  0  8  8  5 16  8  4  8 13 10] ACTION: [18, 1.5] REWARD: -409.51904905584183
# NEW STATE: [ 0 10  4  8  8 16 33  6 17 14 35  8  9  8  1  6  7  8  9 10] ACTION: [18, 1.5] REWARD: -396.57511761421654
# NEW STATE: [ 0 13  4  6 18 17  1  2 21 17  0  7  9  7  9  2  3  5 11 10] ACTION: [18, 1.5] REWARD: -490.9170096632307
# NEW STATE: [ 0 11  6 10 12 14 14  7 16 15 35  7  8  2 19 10  6  8 11 10] ACTION: [18, 1.5] REWARD: -410.83036331119285
# NEW STATE: [ 0 10  4  9  9 14 24  9 22 15 12  9  9  7 10  5  4  6 13 10] ACTION: [18, 1.5] REWARD: -357.651027592578
# NEW STATE: [ 0 10  5  8 12 16 13  6 12 15  6  4 10  3  9  8  5  6  8 10] ACTION: [18, 1.5] REWARD: -342.34855259005894
# NEW STATE: [ 0  8  4  9 10 15 31  7 20 15 30  3  9  7  8  9  6  8 14 10] ACTION: [18, 1.5] REWARD: -404.21987505434197
# NEW STATE: [ 0 12  8 11 11 15 22  6 21 17 45  8  9  8  9 10  5  6  5 10] ACTION: [18, 1.5] REWARD: -412.570844405233
# Average Reward of the Benchmark Policy = -391.45433656777124

# %%
transportCost, holdingCost, lossSales = env.analytics()
# plotting the basic analytics
plt.plot(transportCost, label="Transportation Cost")
plt.plot(holdingCost, label="Holding Cost")
plt.plot(lossSales, label="Loss Sales")
plt.xlabel("Training (100 Days)")
plt.ylabel("Cost")
plt.legend()
plt.show()

# %%
print(f"AVERAGE TRANSPORT COST (LAST 500 DAYS): {np.round(np.array(transportCost[-5:]).mean(), 2)}")
print(f"AVERAGE HOLDING COST (LAST 500 DAYS): {np.round(np.array(holdingCost[-5:]).mean(), 2)}")
print(f"AVERAGE LOSS SALES (LAST 500 DAYS): {np.round(np.array(lossSales[-5:]).mean(), 2)}")
# Out:
# AVERAGE TRANSPORT COST (LAST 500 DAYS): 181.46
# AVERAGE HOLDING COST (LAST 500 DAYS): 201.67
# AVERAGE LOSS SALES (LAST 500 DAYS): 7.71

# %% [markdown]
# **Conclusion**
# <br>
# It can be seen from the above results that similar to the benchmark solution, our model learned to minimize sales loss; however, the holding cost was again stayed rather high. Compared to the benchmark solution where the statistics were:
# - AVERAGE TRANSPORT COST (BENCHMARK): 149.22
# - AVERAGE HOLDING COST (BENCHMARK): 236.94
# - AVERAGE LOSS SALES (BENCHMARK): 37.77
#
# Our improved model was able to significantly improve holding cost and loss sales, however the same cannot be said about the transportation cost.
# <br><br>
# After simulating the policy for 200 days, the average reward observed per day is -391.4. Compared to the simulation result of the benchmark solution where we realized an average reward of -424.4, our new model can be considered as an improved solution to the problem.
# <br><br>
# We believe that our model was stuck in a local optima since it ended up replenishing almost all of the stores each day. We will address these issues in our follow-up models and approaches.
